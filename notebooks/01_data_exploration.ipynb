# %%
import csv
import random
from rdkit.Chem import AllChem, Draw
from pathlib import Path

DATA_PATH = Path("AI4Chem") / "data" / "PolyMetriX" / "processed" / "tg_train.csv"

psmiles_list = []

with DATA_PATH.open(newline="", encoding="utf-8") as file:
    reader = csv.DictReader(file)
    for row in reader:
        psmiles = row["PSMILES"]
        psmiles_list.append(psmiles)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 10
#       6 DATA_PATH = Path("AI4Chem") / "data" / "PolyMetriX" / "processed" / "tg_train.csv"
#       7
#       8 psmiles_list = []
#       9
# ---> 10 with DATA_PATH.open(newline="", encoding="utf-8") as file:
#      11     reader = csv.DictReader(file)
#      12     for row in reader:
#      13         psmiles = row["PSMILES"]
#
# File ~/miniconda3/envs/ai4chem/lib/python3.11/pathlib.py:1044, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1042 if "b" not in mode:
#    1043     encoding = io.text_encoding(encoding)
# -> 1044 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'AI4Chem/data/PolyMetriX/processed/tg_train.csv'

# %%
success_count = 0
failure_count = 0

for psmiles in psmiles_list:
    mol = Chem.MolFromSmiles(psmiles)

    if mol is None:
        failure_count += 1
    else:
        success_count += 1

# %%
fp = AllChem.GetMorganGenerator(radius=2)
