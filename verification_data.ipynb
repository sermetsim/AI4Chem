# %%
import numpy as np


# other
import copy
import time

# data analysis
import pandas as pd


# plot
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.lines import Line2D # legend spe
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import axes3d
fc = '#e0e0e0'
ec = 'black'
csfont = {'fontname':'Times New Roman'}

# fitting
from scipy.optimize import curve_fit
from sklearn.metrics import r2_score


# ODE solver
from scipy.integrate import solve_ivp
from scipy.integrate import odeint
from scipy.optimize import fsolve


# integration
from scipy.integrate import quad      # the_integral = quad(f, initial, final)
from scipy.integrate import trapezoid     # the_int = trapezoid(x= ,y= )
from scipy.interpolate import interp1d      # f = interp1d(x= , y= , kind="linear", bounds_error=False, fill_value="extrapolate")


# minimiser une fonction
from scipy.optimize import minimize_scalar     # the_x_min = (function, bounds=[a,b])

# find root
from scipy.optimize import root     # the_solution = root(function, ini_guess, tol = 1e-12)

# %%
file_path = r"C:\Users\simon\Desktop\Regroupement\IA_for_chemistry\train.csv"    # change le répertoire

values = pd.read_csv(file_path, skiprows=1, skipfooter=0, sep=r',',names = ['id','SMILES','Tg','FFV','Tc','Density','Rg'],engine='python')
try:
    values = values.apply(lambda x: x.str.replace(',','.').astype(float))
except:
    pass

values.head()
# Out:
#        id                                             SMILES  Tg       FFV  \
# 0   87817                         *CC(*)c1ccccc1C(=O)OCCCCCC NaN  0.374645
# 1  106919  *Nc1ccc([C@H](CCC)c2ccc(C3(c4ccc([C@@H](CCC)c5... NaN  0.370410
# 2  388772  *Oc1ccc(S(=O)(=O)c2ccc(Oc3ccc(C4(c5ccc(Oc6ccc(... NaN  0.378860
# 3  519416  *Nc1ccc(-c2c(-c3ccc(C)cc3)c(-c3ccc(C)cc3)c(N*)... NaN  0.387324
# 4  539187  *Oc1ccc(OC(=O)c2cc(OCCCCCCCCCOCC3CCCN3c3ccc([N... NaN  0.355470
#
#          Tc  Density  Rg
# 0  0.205667      NaN NaN
# 1       NaN      NaN NaN
# 2       NaN      NaN NaN
# 3       NaN      NaN NaN
# 4       NaN      NaN NaN

# %%
values['Tg'].count()
# Out:
# np.int64(511)

# %%
values['Tc'].count()
# Out:
# np.int64(737)

# %%
values['Density'].count()
# Out:
# np.int64(613)

# %%
values['FFV'].count()
# Out:
# np.int64(7030)

# %%
condition = values['Tg'].notna() & values['Tc'].notna()

# %%
condition.sum()
# Out:
# np.int64(32)
